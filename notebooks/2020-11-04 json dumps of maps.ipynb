# %%
from pyspark.sql import functions as F

spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-A3EF5O5:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
wzpath = "../../wz-testing-json"
df = spark.read.json(f"{wzpath}/Map.wz/Map/*/*.json", multiLine=True)

# %%
df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- payload: struct (nullable = true)
#  |    |-- 0: struct (nullable = true)
#  |    |    |-- info: string (nullable = true)
#  |    |    |-- obj: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- cx: string (nullable = true)
#  |    |    |    |    |    |-- cy: string (nullable = true)
#  |    |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |    |-- flow: long (nullable = true)
#  |    |    |    |    |    |-- forbidFallDown: long (nullable = true)
#  |    |    |    |    |    |-- l0: string (nullable = true)
#  |    |    |    |    |    |-- l1: string (nullable = true)
#  |    |    |    |    |    |-- l2: string (nullable = true)
#  |    |    |    |    |    |-- oS: string (nullable = true)
#  |    |    |    |    |    |-- r: long (nullable = true)
#  |    |    |    |    |    |-- reactor: long (nullable = true)
#  |    |    |    |    |    |-- rx: string (nullable = true)
#  |    |    |    |    |    |-- ry: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- z: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |    |-- tile: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- no: long (nullable = true)
#  |    |    |    |    |    |-- u: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |-- 1: struct (nullable = true)
#  |    |    |-- info: string (nullable = true)
#  |    |    |-- obj: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- cx: string (nullable = true)
#  |    |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |    |-- flow: long (nullable = true)
#  |    |    |    |    |    |-- forbidFallDown: long (nullable = true)
#  |    |    |    |    |    |-- force: string (nullable = true)
#  |    |    |    |    |    |-- l0: string (nullable = true)
#  |    |    |    |    |    |-- l1: string (nullable = true)
#  |    |    |    |    |    |-- l2: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- oS: string (nullable = true)
#  |    |    |    |    |    |-- r: long (nullable = true)
#  |    |    |    |    |    |-- reactor: long (nullable = true)
#  |    |    |    |    |    |-- rx: string (nullable = true)
#  |    |    |    |    |    |-- ry: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- z: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |    |-- tile: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- no: long (nullable = true)
#  |    |    |    |    |    |-- u: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |-- 2: struct (nullable = true)
#  |    |    |-- info: string (nullable = true)
#  |    |    |-- obj: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- cx: string (nullable = true)
#  |    |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |    |-- flow: long (nullable = true)
#  |    |    |    |    |    |-- force: string (nullable = true)
#  |    |    |    |    |    |-- l0: string (nullable = true)
#  |    |    |    |    |    |-- l1: string (nullable = true)
#  |    |    |    |    |    |-- l2: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- oS: string (nullable = true)
#  |    |    |    |    |    |-- r: long (nullable = true)
#  |    |    |    |    |    |-- reactor: long (nullable = true)
#  |    |    |    |    |    |-- rx: string (nullable = true)
#  |    |    |    |    |    |-- ry: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- z: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |    |-- tile: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- no: long (nullable = true)
#  |    |    |    |    |    |-- u: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |-- 3: struct (nullable = true)
#  |    |    |-- info: string (nullable = true)
#  |    |    |-- obj: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |    |-- flow: long (nullable = true)
#  |    |    |    |    |    |-- forbidFallDown: long (nullable = true)
#  |    |    |    |    |    |-- force: string (nullable = true)
#  |    |    |    |    |    |-- l0: string (nullable = true)
#  |    |    |    |    |    |-- l1: string (nullable = true)
#  |    |    |    |    |    |-- l2: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- oS: string (nullable = true)
#  |    |    |    |    |    |-- r: long (nullable = true)
#  |    |    |    |    |    |-- reactor: long (nullable = true)
#  |    |    |    |    |    |-- rx: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- z: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |    |-- tile: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- no: long (nullable = true)
#  |    |    |    |    |    |-- u: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |-- 4: struct (nullable = true)
#  |    |    |-- info: string (nullable = true)
#  |    |    |-- obj: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- cx: string (nullable = true)
#  |    |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |    |-- flow: long (nullable = true)
#  |    |    |    |    |    |-- forbidFallDown: long (nullable = true)
#  |    |    |    |    |    |-- force: string (nullable = true)
#  |    |    |    |    |    |-- l0: string (nullable = true)
#  |    |    |    |    |    |-- l1: string (nullable = true)
#  |    |    |    |    |    |-- l2: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- oS: string (nullable = true)
#  |    |    |    |    |    |-- r: long (nullable = true)
#  |    |    |    |    |    |-- reactor: long (nullable = true)
#  |    |    |    |    |    |-- rx: string (nullable = true)
#  |    |    |    |    |    |-- ry: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- z: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |    |-- tile: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- no: long (nullable = true)
#  |    |    |    |    |    |-- u: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |-- 5: struct (nullable = true)
#  |    |    |-- info: string (nullable = true)
#  |    |    |-- obj: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- cx: string (nullable = true)
#  |    |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |    |-- flow: long (nullable = true)
#  |    |    |    |    |    |-- forbidFallDown: long (nullable = true)
#  |    |    |    |    |    |-- force: string (nullable = true)
#  |    |    |    |    |    |-- l0: string (nullable = true)
#  |    |    |    |    |    |-- l1: string (nullable = true)
#  |    |    |    |    |    |-- l2: string (nullable = true)
#  |    |    |    |    |    |-- oS: string (nullable = true)
#  |    |    |    |    |    |-- r: long (nullable = true)
#  |    |    |    |    |    |-- reactor: long (nullable = true)
#  |    |    |    |    |    |-- rx: string (nullable = true)
#  |    |    |    |    |    |-- ry: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- z: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |    |-- tile: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- no: long (nullable = true)
#  |    |    |    |    |    |-- u: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |-- 6: struct (nullable = true)
#  |    |    |-- info: string (nullable = true)
#  |    |    |-- obj: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- cx: string (nullable = true)
#  |    |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |    |-- flow: long (nullable = true)
#  |    |    |    |    |    |-- forbidFallDown: long (nullable = true)
#  |    |    |    |    |    |-- l0: string (nullable = true)
#  |    |    |    |    |    |-- l1: string (nullable = true)
#  |    |    |    |    |    |-- l2: string (nullable = true)
#  |    |    |    |    |    |-- oS: string (nullable = true)
#  |    |    |    |    |    |-- r: long (nullable = true)
#  |    |    |    |    |    |-- reactor: long (nullable = true)
#  |    |    |    |    |    |-- rx: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- z: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |    |-- tile: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- no: long (nullable = true)
#  |    |    |    |    |    |-- u: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |-- 7: struct (nullable = true)
#  |    |    |-- info: string (nullable = true)
#  |    |    |-- obj: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |    |-- l0: string (nullable = true)
#  |    |    |    |    |    |-- l1: string (nullable = true)
#  |    |    |    |    |    |-- l2: string (nullable = true)
#  |    |    |    |    |    |-- oS: string (nullable = true)
#  |    |    |    |    |    |-- r: long (nullable = true)
#  |    |    |    |    |    |-- reactor: long (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- z: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |    |-- tile: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- no: long (nullable = true)
#  |    |    |    |    |    |-- u: string (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |    |    |    |-- zM: long (nullable = true)
#  |    |-- BuffZone: struct (nullable = true)
#  |    |    |-- hill: struct (nullable = true)
#  |    |    |    |-- Duration: long (nullable = true)
#  |    |    |    |-- Interval: long (nullable = true)
#  |    |    |    |-- ItemID: long (nullable = true)
#  |    |    |    |-- x1: long (nullable = true)
#  |    |    |    |-- x2: long (nullable = true)
#  |    |    |    |-- y1: long (nullable = true)
#  |    |    |    |-- y2: long (nullable = true)
#  |    |-- ToolTip: string (nullable = true)
#  |    |-- area: string (nullable = true)
#  |    |-- back: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- a: long (nullable = true)
#  |    |    |    |    |-- ani: long (nullable = true)
#  |    |    |    |    |-- bS: string (nullable = true)
#  |    |    |    |    |-- cx: long (nullable = true)
#  |    |    |    |    |-- cy: long (nullable = true)
#  |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |-- front: long (nullable = true)
#  |    |    |    |    |-- no: long (nullable = true)
#  |    |    |    |    |-- rx: long (nullable = true)
#  |    |    |    |    |-- ry: long (nullable = true)
#  |    |    |    |    |-- type: long (nullable = true)
#  |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |-- y: long (nullable = true)
#  |    |-- clock: struct (nullable = true)
#  |    |    |-- height: long (nullable = true)
#  |    |    |-- width: long (nullable = true)
#  |    |    |-- x: long (nullable = true)
#  |    |    |-- y: long (nullable = true)
#  |    |-- coconut: struct (nullable = true)
#  |    |    |-- avatar: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- cap: long (nullable = true)
#  |    |    |    |    |    |    |    |-- clothes: long (nullable = true)
#  |    |    |-- countBombing: long (nullable = true)
#  |    |    |-- countFalling: long (nullable = true)
#  |    |    |-- countHit: long (nullable = true)
#  |    |    |-- countStopped: long (nullable = true)
#  |    |    |-- effectLose: string (nullable = true)
#  |    |    |-- effectWin: string (nullable = true)
#  |    |    |-- eventName: string (nullable = true)
#  |    |    |-- eventObjectName: string (nullable = true)
#  |    |    |-- soundLose: string (nullable = true)
#  |    |    |-- soundWin: string (nullable = true)
#  |    |    |-- timeDefault: long (nullable = true)
#  |    |    |-- timeExpand: long (nullable = true)
#  |    |    |-- timeFinish: long (nullable = true)
#  |    |    |-- timeMessage: long (nullable = true)
#  |    |-- foothold: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |    |-- item: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- forbidFallDown: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- force: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- next: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- prev: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- x1: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- x2: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- y1: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- y2: long (nullable = true)
#  |    |-- healer: struct (nullable = true)
#  |    |    |-- fall: long (nullable = true)
#  |    |    |-- healMax: long (nullable = true)
#  |    |    |-- healMin: long (nullable = true)
#  |    |    |-- healer: string (nullable = true)
#  |    |    |-- rise: long (nullable = true)
#  |    |    |-- x: long (nullable = true)
#  |    |    |-- yMax: long (nullable = true)
#  |    |    |-- yMin: long (nullable = true)
#  |    |-- info: struct (nullable = true)
#  |    |    |-- VRBottom: long (nullable = true)
#  |    |    |-- VRLeft: long (nullable = true)
#  |    |    |-- VRLimit: long (nullable = true)
#  |    |    |-- VRRight: long (nullable = true)
#  |    |    |-- VRTop: long (nullable = true)
#  |    |    |-- allMoveCheck: long (nullable = true)
#  |    |    |-- bgm: string (nullable = true)
#  |    |    |-- blockPBossChange: long (nullable = true)
#  |    |    |-- cloud: long (nullable = true)
#  |    |    |-- decHP: long (nullable = true)
#  |    |    |-- effect: string (nullable = true)
#  |    |    |-- entrustedShop: long (nullable = true)
#  |    |    |-- everlast: long (nullable = true)
#  |    |    |-- fieldLimit: long (nullable = true)
#  |    |    |-- fieldType: long (nullable = true)
#  |    |    |-- fly: long (nullable = true)
#  |    |    |-- forcedReturn: long (nullable = true)
#  |    |    |-- fs: double (nullable = true)
#  |    |    |-- help: string (nullable = true)
#  |    |    |-- hideMinimap: long (nullable = true)
#  |    |    |-- lvLimit: long (nullable = true)
#  |    |    |-- mapDesc: string (nullable = true)
#  |    |    |-- mapMark: string (nullable = true)
#  |    |    |-- mapName: string (nullable = true)
#  |    |    |-- mobRate: double (nullable = true)
#  |    |    |-- moveLimit: long (nullable = true)
#  |    |    |-- onFirstUserEnter: string (nullable = true)
#  |    |    |-- onUserEnter: string (nullable = true)
#  |    |    |-- personalShop: long (nullable = true)
#  |    |    |-- protectItem: long (nullable = true)
#  |    |    |-- rain: long (nullable = true)
#  |    |    |-- reactorShuffle: long (nullable = true)
#  |    |    |-- reactorShuffleName: string (nullable = true)
#  |    |    |-- recovery: long (nullable = true)
#  |    |    |-- returnMap: long (nullable = true)
#  |    |    |-- scrollDisable: long (nullable = true)
#  |    |    |-- snow: long (nullable = true)
#  |    |    |-- streetName: string (nullable = true)
#  |    |    |-- swim: long (nullable = true)
#  |    |    |-- timeLimit: long (nullable = true)
#  |    |    |-- timeMob: struct (nullable = true)
#  |    |    |    |-- endHour: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- message: string (nullable = true)
#  |    |    |    |-- startHour: long (nullable = true)
#  |    |    |-- town: long (nullable = true)
#  |    |    |-- version: long (nullable = true)
#  |    |    |-- zakum2Hack: long (nullable = true)
#  |    |-- ladderRope: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- l: long (nullable = true)
#  |    |    |    |    |-- page: long (nullable = true)
#  |    |    |    |    |-- uf: long (nullable = true)
#  |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |-- y1: long (nullable = true)
#  |    |    |    |    |-- y2: long (nullable = true)
#  |    |-- life: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- cy: long (nullable = true)
#  |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |-- fh: long (nullable = true)
#  |    |    |    |    |-- hide: long (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- info: long (nullable = true)
#  |    |    |    |    |-- limitedname: string (nullable = true)
#  |    |    |    |    |-- mobTime: long (nullable = true)
#  |    |    |    |    |-- rx0: long (nullable = true)
#  |    |    |    |    |-- rx1: long (nullable = true)
#  |    |    |    |    |-- team: long (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |-- y: long (nullable = true)
#  |    |-- miniMap: struct (nullable = true)
#  |    |    |-- canvas: struct (nullable = true)
#  |    |    |    |-- height: long (nullable = true)
#  |    |    |    |-- width: long (nullable = true)
#  |    |    |-- centerX: long (nullable = true)
#  |    |    |-- centerY: long (nullable = true)
#  |    |    |-- height: long (nullable = true)
#  |    |    |-- mag: long (nullable = true)
#  |    |    |-- width: long (nullable = true)
#  |    |-- monsterCarnival: struct (nullable = true)
#  |    |    |-- deathCP: long (nullable = true)
#  |    |    |-- effectLose: string (nullable = true)
#  |    |    |-- effectWin: string (nullable = true)
#  |    |    |-- guardian: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- 0: long (nullable = true)
#  |    |    |    |    |    |-- 1: long (nullable = true)
#  |    |    |    |    |    |-- 2: long (nullable = true)
#  |    |    |    |    |    |-- 3: long (nullable = true)
#  |    |    |    |    |    |-- 4: long (nullable = true)
#  |    |    |    |    |    |-- 5: long (nullable = true)
#  |    |    |    |    |    |-- 6: long (nullable = true)
#  |    |    |    |    |    |-- 7: long (nullable = true)
#  |    |    |    |    |    |-- 8: long (nullable = true)
#  |    |    |-- guardianGenMax: long (nullable = true)
#  |    |    |-- guardianGenPos: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |    |-- team: long (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |-- mapDivided: long (nullable = true)
#  |    |    |-- mob: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- mobTime: long (nullable = true)
#  |    |    |    |    |    |-- spendCP: long (nullable = true)
#  |    |    |-- mobGenMax: long (nullable = true)
#  |    |    |-- mobGenPos: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- cy: long (nullable = true)
#  |    |    |    |    |    |-- fh: long (nullable = true)
#  |    |    |    |    |    |-- team: long (nullable = true)
#  |    |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |    |-- y: long (nullable = true)
#  |    |    |-- reactorBlue: long (nullable = true)
#  |    |    |-- reactorRed: long (nullable = true)
#  |    |    |-- reward: struct (nullable = true)
#  |    |    |    |-- climax: double (nullable = true)
#  |    |    |    |-- cpDiff: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |    |-- 0: long (nullable = true)
#  |    |    |    |    |    |    |-- 1: long (nullable = true)
#  |    |    |    |    |    |    |-- 2: long (nullable = true)
#  |    |    |    |-- probChange: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |    |-- loseCP: double (nullable = true)
#  |    |    |    |    |    |    |-- loseCoin: double (nullable = true)
#  |    |    |    |    |    |    |-- loseNuff: double (nullable = true)
#  |    |    |    |    |    |    |-- loseRecovery: double (nullable = true)
#  |    |    |    |    |    |    |-- wInCoin: double (nullable = true)
#  |    |    |    |    |    |    |-- winCP: double (nullable = true)
#  |    |    |    |    |    |    |-- winNuff: double (nullable = true)
#  |    |    |    |    |    |    |-- winRecovery: double (nullable = true)
#  |    |    |-- rewardMapLose: long (nullable = true)
#  |    |    |-- rewardMapWin: long (nullable = true)
#  |    |    |-- skill: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- index: long (nullable = true)
#  |    |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |    |-- 0: long (nullable = true)
#  |    |    |    |    |    |-- 1: long (nullable = true)
#  |    |    |    |    |    |-- 2: long (nullable = true)
#  |    |    |    |    |    |-- 3: long (nullable = true)
#  |    |    |    |    |    |-- 4: long (nullable = true)
#  |    |    |    |    |    |-- 5: long (nullable = true)
#  |    |    |    |    |    |-- 6: long (nullable = true)
#  |    |    |    |    |    |-- 7: long (nullable = true)
#  |    |    |-- soundLose: string (nullable = true)
#  |    |    |-- soundWin: string (nullable = true)
#  |    |    |-- timeDefault: long (nullable = true)
#  |    |    |-- timeExpand: long (nullable = true)
#  |    |    |-- timeFinish: long (nullable = true)
#  |    |    |-- timeMessage: long (nullable = true)
#  |    |-- portal: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- delay: long (nullable = true)
#  |    |    |    |    |-- hideTooltip: long (nullable = true)
#  |    |    |    |    |-- image: string (nullable = true)
#  |    |    |    |    |-- onlyOnce: long (nullable = true)
#  |    |    |    |    |-- pn: string (nullable = true)
#  |    |    |    |    |-- pt: long (nullable = true)
#  |    |    |    |    |-- script: string (nullable = true)
#  |    |    |    |    |-- tm: long (nullable = true)
#  |    |    |    |    |-- tn: string (nullable = true)
#  |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |-- y: long (nullable = true)
#  |    |-- pulley: struct (nullable = true)
#  |    |    |-- pulley: string (nullable = true)
#  |    |    |-- x: long (nullable = true)
#  |    |    |-- y: long (nullable = true)
#  |    |-- reactor: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- f: long (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- reactorTime: long (nullable = true)
#  |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |-- y: long (nullable = true)
#  |    |-- seat: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- x: long (nullable = true)
#  |    |    |    |    |-- y: long (nullable = true)
#  |    |-- shipObj: struct (nullable = true)
#  |    |    |-- f: long (nullable = true)
#  |    |    |-- shipKind: long (nullable = true)
#  |    |    |-- shipObj: string (nullable = true)
#  |    |    |-- tMove: long (nullable = true)
#  |    |    |-- x: long (nullable = true)
#  |    |    |-- x0: long (nullable = true)
#  |    |    |-- y: long (nullable = true)
#  |    |    |-- z: long (nullable = true)
#  |    |-- snowBall: struct (nullable = true)
#  |    |    |-- 0: struct (nullable = true)
#  |    |    |    |-- portal: string (nullable = true)
#  |    |    |    |-- snowBall: string (nullable = true)
#  |    |    |    |-- snowMan: string (nullable = true)
#  |    |    |    |-- y: long (nullable = true)
#  |    |    |-- 1: struct (nullable = true)
#  |    |    |    |-- portal: string (nullable = true)
#  |    |    |    |-- snowBall: string (nullable = true)
#  |    |    |    |-- snowMan: string (nullable = true)
#  |    |    |    |-- y: long (nullable = true)
#  |    |    |-- damageSnowBall: string (nullable = true)
#  |    |    |-- damageSnowMan0: long (nullable = true)
#  |    |    |-- damageSnowMan1: long (nullable = true)
#  |    |    |-- dx: long (nullable = true)
#  |    |    |-- recoveryAmount: long (nullable = true)
#  |    |    |-- section1: long (nullable = true)
#  |    |    |-- section2: long (nullable = true)
#  |    |    |-- section3: long (nullable = true)
#  |    |    |-- snowManHP: long (nullable = true)
#  |    |    |-- snowManWait: long (nullable = true)
#  |    |    |-- speed: long (nullable = true)
#  |    |    |-- x: long (nullable = true)
#  |    |    |-- x0: long (nullable = true)
#  |    |    |-- xMax: long (nullable = true)
#  |    |    |-- xMin: long (nullable = true)
#  |    |-- swimArea: struct (nullable = true)
#  |    |    |-- nt: struct (nullable = true)
#  |    |    |    |-- x1: long (nullable = true)
#  |    |    |    |-- x2: long (nullable = true)
#  |    |    |    |-- y1: long (nullable = true)
#  |    |    |    |-- y2: long (nullable = true)
#  |    |    |-- pw00: struct (nullable = true)
#  |    |    |    |-- x1: long (nullable = true)
#  |    |    |    |-- x2: long (nullable = true)
#  |    |    |    |-- y1: long (nullable = true)
#  |    |    |    |-- y2: long (nullable = true)
#  |    |-- weather: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- item: string (nullable = true)
#  |    |    |    |    |-- msg: string (nullable = true)
#  |    |    |    |    |-- option: long (nullable = true)
#  |    |    |    |    |-- time: long (nullable = true)

# %%
df.select("name", "payload.info.*").select("name", "help", "mapDesc", "mapMark", "mapName", "streetName", "town").show(n=100)
# Out:
# +-------------+----+-------+-------------+--------+----------+----+
# |         name|help|mapDesc|      mapMark| mapName|streetName|town|
# +-------------+----+-------+-------------+--------+----------+----+
# |105090000.img|null|       |      Dungeon|    null|      null|   0|
# |103000900.img|null|       |        Quest|2??<1??>|   ???????|   0|
# |680000000.img|null|   null|      Wedding|    null|      null|   1|
# |104010000.img|null|       |         Rith|    null|      null|   0|
# |109010100.img|null|       |        Event|    null|      null|   0|
# |670010600.img|null|   null|      Wedding|    null|      null|   0|
# |682000700.img|null|   null|    Halloween|    null|      null|   0|
# |229030400.img|null|   null|HuntedMansion|    null|      null|   0|
# |229030700.img|null|   null|HuntedMansion|    null|      null|   0|
# |229030000.img|null|   null|HuntedMansion|    null|      null|   0|
# |990000440.img|null|   null|        Guild|    null|      null|   1|
# |105070001.img|null|       |      Dungeon|    null|      null|   0|
# |105090100.img|null|   null|      Dungeon|    null|      null|   0|
# |109080002.img|null|       |        Event|    null|      null|   0|
# |109080001.img|null|       |        Event|    null|      null|   0|
# |109080003.img|null|       |        Event|    null|      null|   0|
# |109080000.img|null|       |        Event|    null|      null|   0|
# |105060000.img|null|       |      Dungeon|    null|      null|   0|
# |600020400.img|null|   null|          NLC|    null|      null|   0|
# |600020200.img|null|   null|          NLC|    null|      null|   0|
# |101000000.img|null|   null|      Ellinia|    null|      null|   1|
# |103000904.img|null|       |        Quest|2??<1??>|   ???????|   1|
# |105090300.img|null|   null|      Dungeon|    null|      null|   0|
# |105070000.img|null|       |      Dungeon|    null|      null|   0|
# |682000900.img|null|   null|    Halloween|    null|      null|   0|
# |103000906.img|null|       |        Quest|2??<1??>|   ???????|   0|
# |101020000.img|null|       |      Ellinia|    null|      null|   0|
# |104000000.img|null|   null|         Rith|    null|      null|   1|
# |682000200.img|null|   null|    Halloween|    null|      null|   0|
# |100030000.img|null|       |      Henesys|    null|      null|   0|
# |105090310.img|null|       |      Dungeon|    null|      null|   0|
# |670010200.img|null|   null|      Wedding|    null|      null|   0|
# |103000000.img|null|   null|  KerningCity|    null|      null|   1|
# |105050100.img|null|       |      Dungeon|    null|      null|   0|
# |600020100.img|null|   null|          NLC|    null|      null|   0|
# |280020001.img|null|   null|ElNathDungeon|    null|      null|   0|
# |670010750.img|null|   null|      Wedding|    null|      null|   0|
# |105050200.img|null|       |      Dungeon|    null|      null|   0|
# |600020000.img|null|   null|          NLC|    null|      null|   0|
# |101030000.img|null|       |       Perion|    null|      null|   0|
# |105050300.img|null|       |      Dungeon|    null|      null|   0|
# |103000903.img|null|       |        Quest|2??<1??>|   ???????|   0|
# |105030000.img|null|       |      Dungeon|    null|      null|   0|
# |922000010.img|null|   null|   LudiTower1|    null|      null|   0|
# |107000000.img|null|       |  KerningCity|    null|      null|   0|
# |103010000.img|null|   null|  KerningCity|    null|      null|   0|
# |105060100.img|null|       |      Dungeon|    null|      null|   0|
# |221022200.img|null|   null|   LudiTower1|    null|      null|   0|
# |280020000.img|null|   null|ElNathDungeon|    null|      null|   0|
# |120000000.img|null|   null|     Nautilus|    null|      null|   1|
# |610020001.img|null|   null|  Crimsonwood|    null|      null|   0|
# |107000100.img|null|       |  KerningCity|    null|      null|   0|
# |103000908.img|null|       |        Quest|2??<1??>|   ???????|   0|
# |211042200.img|null|   null|ElNathDungeon|    null|      null|   0|
# |107000200.img|null|       |  KerningCity|    null|      null|   0|
# |109030003.img|null|       |        Event|    null|      null|   0|
# |900000000.img|null|   null|        Quest|    null|      null|   0|
# |600010400.img|null|   null|          NLC|    null|      null|   0|
# |105050000.img|null|       |      Dungeon|    null|      null|   0|
# |109030403.img|null|       |        Event|    null|      null|   0|
# |109030203.img|null|       |        Event|    null|      null|   0|
# |109030303.img|null|       |        Event|    null|      null|   1|
# |109030103.img|null|       |        Event|    null|      null|   0|
# |600010500.img|null|   null|          NLC|    null|      null|   0|
# |107000300.img|null|       |  KerningCity|    null|      null|   0|
# |222000000.img|null|   null|  Folkvillige|    null|      null|   1|
# |109010200.img|null|       |        Event|    null|      null|   0|
# |105090311.img|null|       |      Dungeon|    null|      null|   0|
# |250000000.img|null|   null|      Murueng|    null|      null|   1|
# |107000400.img|null|       |  KerningCity|    null|      null|   0|
# |105070100.img|null|       |      Dungeon|    null|      null|   0|
# |200000000.img|null|   null|        Orbis|    null|      null|   1|
# |600000000.img|null|   null|          NLC|    null|      null|   1|
# |221030000.img|null|   null|  OmegaSector|    null|      null|   0|
# |100040000.img|null|       |      Ellinia|    null|      null|   0|
# |106010000.img|null|   null|      Henesys|    null|      null|   0|
# |104030000.img|null|       |      Henesys|    null|      null|   0|
# |230020200.img|null|   null|     AquaRoad|    null|      null|   0|
# |105070400.img|null|       |      Dungeon|    null|      null|   0|
# |108000100.img|null|       |      Henesys|    null|      null|   0|
# |108000101.img|null|       |      Henesys|    null|      null|   0|
# |108000102.img|null|       |      Henesys|    null|      null|   0|
# |990000410.img|null|   null|        Guild|    null|      null|   1|
# |102030000.img|null|   null|       Perion|    null|      null|   0|
# |100000000.img|null|   null|      Henesys|    null|      null|   1|
# |600020500.img|null|   null|          NLC|    null|      null|   0|
# |920010700.img|null|   null| GoddessTower|    null|      null|   0|
# |105070300.img|null|       |      Dungeon|    null|      null|   0|
# |105040000.img|null|       |      Dungeon|    null|      null|   0|
# |107000401.img|null|       |  KerningCity|    null|      null|   0|
# |107000001.img|null|       |  KerningCity|    null|      null|   0|
# |105090400.img|null|       |      Dungeon|    null|      null|   0|
# |211042000.img|null|   null|ElNathDungeon|    null|      null|   0|
# |100000202.img|null|       |      Henesys|        |      ????|   1|
# |922011000.img|null|   null| AbandonTower|    null|      null|   0|
# |105080000.img|null|       |      Dungeon|    null|      null|   0|
# |109040003.img|null|       |        Event|    null|      null|   1|
# |100000203.img|null|       |      Henesys|    null|      null|   1|
# |102000000.img|null|   null|       Perion|    null|      null|   1|
# |211042100.img|null|   null|ElNathDungeon|    null|      null|   0|
# +-------------+----+-------+-------------+--------+----------+----+
# only showing top 100 rows

# %%
portals = (
    df.select("name", "payload.info.returnMap", "payload.portal")
    .withColumn("portal", F.explode("portal"))
    .select("name", "returnMap", "portal.item.*")
)
portals.show(n=10)
# Out:
# +-------------+---------+-----+-----------+-----+--------+------+---+------+---------+------+----+----+
# |         name|returnMap|delay|hideTooltip|image|onlyOnce|    pn| pt|script|       tm|    tn|   x|   y|
# +-------------+---------+-----+-----------+-----+--------+------+---+------+---------+------+----+----+
# |105090000.img|105040300| null|       null| null|    null|    sp|  0|  null|999999999|      |-343| -81|
# |105090000.img|105040300| null|       null| null|    null|    sp|  0|  null|999999999|      |-277| -80|
# |105090000.img|105040300| null|       null| null|    null|    sp|  0|  null|999999999|      |-217| -80|
# |105090000.img|105040300| null|       null| null|    null|    sp|  0|  null|999999999|      |  -6| -51|
# |105090000.img|105040300| null|       null| null|    null|    sp|  0|  null|999999999|      |  38|  -4|
# |105090000.img|105040300| null|       null| null|    null|west00|  2|  null|105080000|east01|-324|  17|
# |105090000.img|105040300| null|       null| null|    null|east00|  2|  null|105090100|west00|2199|3369|
# |103000900.img|103000000| null|       null| null|    null|    sp|  0|  null|999999999|      |-569| 160|
# |103000900.img|103000000| null|       null| null|    null|  st00|  1|  null|999999999|      |-606| 194|
# |103000900.img|103000000| null|       null| null|    null| out02|  1|  null|999999999|      |1704|-829|
# +-------------+---------+-----+-----------+-----+--------+------+---+------+---------+------+----+----+
# only showing top 10 rows

# %% [markdown]
# https://github.com/lastbattle/Harepacker-resurrected/blob/c8e3a7ce4cd9f9735230369a8af6605de241077e/HaCreator/MapEditor/Info/PortalInfo.cs#L42-L87
#
# * `pn` - this column contains the spawn points. `sp` is short for start point (found by looking at the particular element in HaCreator).
# * `pt` is portal type?

# %%
portals.groupBy("pt").agg(F.count("*"), F.countDistinct("tm")).orderBy("pt").show()
# Out:
# +---+--------+---------+
# | pt|count(1)|count(tm)|
# +---+--------+---------+
# |  0|    4245|        1|
# |  1|    2573|      511|
# |  2|    1525|      667|
# |  3|     651|       98|
# |  4|       9|        9|
# |  5|      20|       16|
# |  6|     158|        1|
# |  7|     250|        1|
# |  8|     209|        1|
# |  9|      38|        1|
# | 10|      79|       33|
# | 11|       2|        1|
# +---+--------+---------+

# %% [markdown]
# https://github.com/lastbattle/Harepacker-resurrected/blob/59335ea6fa699fd2f78bf2aee5169535b1093485/MapleLib/WzLib/WzStructure/Data/PortalType.cs
# ```
# PORTALTYPE_STARTPOINT = "sp",
# PORTALTYPE_INVISIBLE = "pi",
# PORTALTYPE_VISIBLE = "pv",
# PORTALTYPE_COLLISION = "pc",
# PORTALTYPE_CHANGABLE = "pg",
# PORTALTYPE_CHANGABLE_INVISIBLE = "pgi",
# PORTALTYPE_TOWNPORTAL_POINT = "tp",
# PORTALTYPE_SCRIPT = "ps",
# PORTALTYPE_SCRIPT_INVISIBLE = "psi",
# PORTALTYPE_COLLISION_SCRIPT = "pcs",
# PORTALTYPE_HIDDEN = "ph",
# PORTALTYPE_SCRIPT_HIDDEN = "psh",
# PORTALTYPE_COLLISION_VERTICAL_JUMP = "pcj",
# PORTALTYPE_COLLISION_CUSTOM_IMPACT = "pci",
# PORTALTYPE_COLLISION_UNKNOWN_PCIG = "pcig",
# PORTALTYPE_SCRIPT_HIDDEN_UNG = "pshg";
# ```

# %%
portals.groupBy("pn").count().orderBy(F.desc("count")).show(n=10)
# Out:
# +-------+-----+
# |     pn|count|
# +-------+-----+
# |     sp| 4240|
# |  out00|  547|
# |   st00|  321|
# | west00|  307|
# | east00|  287|
# |   in00|  225|
# |     tp|  163|
# |  top00|  155|
# |under00|  145|
# |   h001|   92|
# +-------+-----+
# only showing top 10 rows

# %%
portals.where(F.col("pn")!="sp").where("tm <> 999999999").show()
# Out:
# +-------------+---------+-----+-----------+-----+--------+-------+---+------+---------+-------+-----+----+
# |         name|returnMap|delay|hideTooltip|image|onlyOnce|     pn| pt|script|       tm|     tn|    x|   y|
# +-------------+---------+-----+-----------+-----+--------+-------+---+------+---------+-------+-----+----+
# |105090000.img|105040300| null|       null| null|    null| west00|  2|  null|105080000| east01| -324|  17|
# |105090000.img|105040300| null|       null| null|    null| east00|  2|  null|105090100| west00| 2199|3369|
# |103000900.img|103000000| null|       null| null|    null|   in00|  2|  null|103000900|  out00|  252|-230|
# |103000900.img|103000000| null|       null| null|    null|  out00|  2|  null|103000900|   in00| -544|-521|
# |103000900.img|103000000| null|       null| null|    null|   in02|  2|  null|103000900|  out02| 1159|-950|
# |103000900.img|103000000| null|       null| null|    null|   in04|  2|  null|103000900| last00| 3281|-859|
# |103000900.img|103000000| null|       null| null|    null|   in01|  2|  null|103000900|  out01| 1257| 321|
# |103000900.img|103000000| null|       null| null|    null|  out01|  2|  null|103000900|   in01| 1208| 701|
# |103000900.img|103000000| null|       null| null|    null|   in03|  2|  null|103000900|  out03| 1214|1162|
# |103000900.img|103000000| null|       null| null|    null|   in05|  2|  null|103000900| last00| 3303| 821|
# |103000900.img|103000000| null|       null| null|    null|  end00|  2|  null|103000901|   st00| 3284|  40|
# |103000900.img|103000000| null|       null| null|    null|cross00|  2|  null|103000900|cross01| -361|1160|
# |103000900.img|103000000| null|       null| null|    null|cross01|  2|  null|103000900|cross00|  -68|1159|
# |680000000.img|680000000| null|       null| null|    null|   in02|  1|      |680000002|  out01| 3097| 515|
# |680000000.img|680000000| null|       null| null|    null|   in03|  1|      |680000003|  out03| 1821| 496|
# |680000000.img|680000000| null|       null| null|    null|   in00|  1|      |680000001|  out00|-1329| 500|
# |680000000.img|680000000| null|       null| null|    null|   bo00|  1|  null|680000000|   mi00|  -48| 187|
# |680000000.img|680000000| null|       null| null|    null|   mi00|  1|  null|680000000|   to00|  -46|-143|
# |680000000.img|680000000|    0|          0| null|    null|   to00|  1|      |680000000|   to01|  -45|-341|
# |680000000.img|680000000| null|       null| null|    null|   bo01|  1|  null|680000000|   mi01|  432| 188|
# +-------------+---------+-----+-----------+-----+--------+-------+---+------+---------+-------+-----+----+
# only showing top 20 rows

# %%
portalEdges = (
    portals
    .where(F.col("pn")!="sp")
    .where("tm <> 999999999")
    .select(F.split("name", "\.")[0].alias("map"), F.col("tm").alias("portal"), "returnMap")
    .where("map <> portal")
    .distinct()
)
portalEdges.count()
# Out:
# 2087

# %%
portalEdges.show()
# Out:
# +---------+---------+---------+
# |      map|   portal|returnMap|
# +---------+---------+---------+
# |680000000|680000001|680000000|
# |104010000|104010002|104000000|
# |229030000|229030100|229030300|
# |105090100|105090200|105040300|
# |101000000|100050000|101000000|
# |103000000|103000001|103000000|
# |103000000|103000005|103000000|
# |103000000|103000100|103000000|
# |103000000|103010000|103000000|
# |280020001|280020000|211000000|
# |105050200|105050300|105040300|
# |600020000|600020100|600000000|
# |221022200|221022100|221000000|
# |600010400|600010500|600000000|
# |109030203|109050000|109050001|
# |109010200|109010201|109050001|
# |250000000|250000001|999999999|
# |250000000|250000002|999999999|
# |107000400|107000500|103000000|
# |600000000|600010100|600000000|
# +---------+---------+---------+
# only showing top 20 rows

# %%
portalEdges.groupBy("returnMap").agg(F.countDistinct("map").alias("n")).orderBy(F.desc("n")).show()
# Out:
# +---------+---+
# |returnMap|  n|
# +---------+---+
# |220000000| 97|
# |682000000| 66|
# |240000000| 58|
# |200000000| 58|
# |211000000| 57|
# |105040300| 52|
# |102000000| 50|
# |221000000| 49|
# |103000000| 45|
# |101000000| 39|
# |109050001| 38|
# |100000000| 36|
# |260000000| 35|
# |230000000| 33|
# |280090000| 30|
# |910000000| 23|
# |250000000| 21|
# |922010000| 20|
# |222000000| 20|
# |990000200| 20|
# +---------+---+
# only showing top 20 rows

# %%
edges = (
    portalEdges
    .select(F.col("map").alias("src"), F.col("portal").alias("dst"), F.lit("portal").alias("type"))
    .union(portalEdges.select(F.col("returnMap").alias("src"), F.col("map").alias("dst"), F.lit("return").alias("type")))
)

(
    edges
    .selectExpr("src as Source", "dst as Target", "type as Label")
    .toPandas()
    .to_csv("../data/processed/map-portals.csv", index=False)
)

# %%
mapStrings = spark.read.json(f"{wzpath}/String.wz/Map*.json", multiLine=True)
mapStrings.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- payload: struct (nullable = true)
#  |    |-- HalloweenGL: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- mapName: string (nullable = true)
#  |    |    |    |    |-- streetName: string (nullable = true)
#  |    |-- MasteriaGL: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- mapName: string (nullable = true)
#  |    |    |    |    |-- streetName: string (nullable = true)
#  |    |-- etc: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- mapName: string (nullable = true)
#  |    |    |    |    |-- streetName: string (nullable = true)
#  |    |-- jp: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- mapName: string (nullable = true)
#  |    |    |    |    |-- streetName: string (nullable = true)
#  |    |-- maple: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- help0: string (nullable = true)
#  |    |    |    |    |-- mapDesc: string (nullable = true)
#  |    |    |    |    |-- mapName: string (nullable = true)
#  |    |    |    |    |-- streetName: string (nullable = true)
#  |    |-- ossyria: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- help0: string (nullable = true)
#  |    |    |    |    |-- help1: string (nullable = true)
#  |    |    |    |    |-- mapDesc: string (nullable = true)
#  |    |    |    |    |-- mapName: string (nullable = true)
#  |    |    |    |    |-- streetName: string (nullable = true)
#  |    |-- singapore: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- mapName: string (nullable = true)
#  |    |    |    |    |-- streetName: string (nullable = true)
#  |    |-- victoria: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- help0: string (nullable = true)
#  |    |    |    |    |-- help1: string (nullable = true)
#  |    |    |    |    |-- mapDesc: string (nullable = true)
#  |    |    |    |    |-- mapName: string (nullable = true)
#  |    |    |    |    |-- streetName: string (nullable = true)
#  |    |-- weddingGL: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- index: long (nullable = true)
#  |    |    |    |-- item: struct (nullable = true)
#  |    |    |    |    |-- mapName: string (nullable = true)
#  |    |    |    |    |-- streetName: string (nullable = true)

# %%
victoria = mapStrings.select(F.explode("payload.victoria")).select("col.index", "col.item.*")
victoria.show()
# Out:
# +---------+-----+-----+--------------------+--------------------+-------------+
# |    index|help0|help1|             mapDesc|             mapName|   streetName|
# +---------+-----+-----+--------------------+--------------------+-------------+
# |100000000| null| null|It's a bowman tow...|             Henesys|Victoria Road|
# |100000001| null| null|                null|  Henesys Townstreet|Victoria Road|
# |100000002| null| null|                null|      An Empty House|Hidden Street|
# |100000003| null| null|                null|            Pig Park|Hidden Street|
# |100000004| null| null|                null|         Pig Park II|Hidden Street|
# |100000005| null| null|                null|Someone Else's House|Hidden Street|
# |100000006| null| null|                null|The Resting Spot,...|Hidden Street|
# |100000100| null| null|                null|      Henesys Market|Victoria Road|
# |100000101| null| null|                null|Henesys Weapon Store|Victoria Road|
# |100000102| null| null|                null|Henesys Departmen...|Victoria Road|
# |100000103| null| null|                null|Henesys Plastic S...|Victoria Road|
# |100000104| null| null|                null|  Henesys Hair Salon|Victoria Road|
# |100000105| null| null|                null|   Henesys Skin-Care|Victoria Road|
# |100000110| null| null|                null|Henesys Free Mark...|Victoria Road|
# |100000111| null| null|                null|Henesys Free Mark...|Victoria Road|
# |100000112| null| null|                null|Henesys Free Mark...|Victoria Road|
# |100000113| null| null|                null|Henesys Free Mark...|Victoria Road|
# |100000114| null| null|                null|Henesys Free Mark...|Victoria Road|
# |100000115| null| null|                null|Henesys Free Mark...|Victoria Road|
# |100000116| null| null|                null|Henesys Free Mark...|Victoria Road|
# +---------+-----+-----+--------------------+--------------------+-------------+
# only showing top 20 rows

# %%
(
    edges
    .join(victoria.select(F.col("index").alias("src")), on="src")
    .join(victoria.select(F.col("index").alias("dst")), on="dst")
    .selectExpr("src as Source", "dst as Target", "type as Label")
    .toPandas()
    .to_csv("../data/processed/victoria-portal-edges.csv", index=False)
)

(
    victoria
    .select(F.col("index").alias("Id"), F.concat("streetName", F.lit(": "), "mapName").alias("Label"))
    .toPandas()
    .to_csv("../data/processed/victoria-portal-nodes.csv", index=False)
)
